# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
L = 1e5
# http://ascelibrary.org/doi/full/10.1061/(ASCE)CR.1943-5495.0000035
E = 0.72e6
nu = 0.25
h = 200.0
D = E*h**3/(12*(1-nu**2))
q = 100*9.8*h # drho * g * h
V = 100*9.8
x = np.linspace(0,L,101)
q_over_D = q/D

# %%
#plt.plot(x, q_over_D*x**2*(x**2/24.0-L*x/6.0+L**2/4))
plt.plot(x,0.5*V/D*x**2*(L-x/3))
# Out:
# <img src="data:image/png;base64,...">
